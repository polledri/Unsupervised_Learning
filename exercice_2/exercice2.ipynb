# %%
from CustomPCA import CustomPCA
import numpy as np

data = np.load('data.npy')
labels = np.load('labels.npy')

# %% [markdown]
# coucou

# %%
pca_2d = CustomPCA(2)
pca_2d.simulation(data, labels)

# %%
pca_3d = CustomPCA(3)
pca_3d.simulation(data, labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 pca_3d = CustomPCA(3)
# ----> 2 pca_3d.simulation(data, labels)
#
# File ~/Documents/Unsupervised_Learning/exercice_2/CustomPCA.py:42, in CustomPCA.simulation(self, data, labels)
#      40 legend = plt.colorbar(scatter)
#      41 legend.set_label('Labels')
# ---> 42 plt.plot(self.pca.singular_values_)
#      43 plt.title("Valeur propres de la matrice de covariance")
#      44 plt.ylabel("vp")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# TypeError: Axes3D.plot() missing 1 required positional argument: 'ys'
